# %% [markdown]
# # **Lab 10 - Visión Por Computadora**
#
# Integrantes:
# - Francis Aguilar, 22243
# - César López, 22535
# - Jose Marchena, 22398
#
# Repo:
# https://github.com/faguilarleal/lab10_vision
